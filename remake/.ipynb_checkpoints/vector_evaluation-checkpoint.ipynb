# %%
import json
import os
import numpy as np
import time
from sklearn.decomposition import PCA
from sklearn import manifold
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
from scipy.spatial import distance
from scipy import stats
import random

# %%
def load_data(path):
    data = []
    res = []
    if path.endswith('json'):
        with open(path, 'r') as f:
            data = json.loads(f.readline())
    return data

def get_data_by_idx(data, idx):
    print('get data by idx: ', idx)
    res = []
    for i in idx:
        res.append(data[i])
    print('number of items: ', len(res))
    return res

def show_idbench_data(data):
    for i in range(1):
        for j in range(len(data[i])):
            print(data[i][j][0])
            print(data[i][j][1][0], data[i][j][2][0])

# %%
def get_tokens(info):
    toks = []
    for i in info:
        if i[1] not in toks:
            toks.append(i[1])
        if i[3] not in toks:
            toks.append(i[3])
    return toks

def build_pca_data(data):
    res_idx = []
    res_features = []
    for i in range(len(data)):
        for j in range(len(data[i])):
            res_idx.append([i, j])
            res_features.append(data[i][j])
    print(res_features[0])
    return res_idx, res_features
        
def pca(data):
    # data as a list
    pca = PCA(n_components=2)
    principalComponents = pca.fit_transform(data)
    return principalComponents

def tsne(data):
    tsne = manifold.TSNE(n_components=2, init='pca', random_state=501)
    X_tsne = tsne.fit_transform(data)
    return X_tsne

def visualize(data, info, show_all=True, show_label=True):
    fig = plt.figure()
    ax = fig.add_subplot(1,1,1) 
    ax.set_xlabel('Principal Component 1', fontsize = 15)
    ax.set_ylabel('Principal Component 2', fontsize = 15)
    ax.set_title('2 component TSNE', fontsize = 20)
    
    targets = [0, 1, 2]
    colors = ['r', 'g', 'b', 'c', 'm', 'y', 'k']
    colors = colors[:len(targets)]
    
    for target, color in zip(targets, colors):
        x = []
        y = []
        labels = []
        for i in range(len(info)):
            if info[i][0] == target:
                x.append(data[i][0])
                y.append(data[i][1])
                labels.append(info[i][1])
        
        ax.scatter(x, y, c = color, s = 20)
        
        if show_label:
            for i, txt in enumerate(labels):
                ax.annotate(txt, (x[i], y[i]))
                
    
    ax.legend(targets)

    '''
    for i in info:
        
        x = [i[0] for i in data]
        y = [i[1] for i in data]
    
    ax.scatter(x, y)
    '''
    ax.grid()

# %%
data_path = './results/val_embedding.json'


def analyze_graph_with_idx_in_local(idx=[0, 1, 2]):
    data = load_data(data_path)
    fd = get_data_by_idx(data, [0, 1, 2])
    fd_idx, fd_ebd = build_pca_data(fd)
    tsne_fd = tsne(fd_ebd)
    print(tsne_fd)
    # print(fd_context)
    visualize(tsne_fd, fd_idx)
    
    
def analyze_idbench_with_tok_equal_in_global():
    idbench_data_path = './idbench_res_id2vec-textcnn_js_2_epoch_4_with_embeddings.json'
    idbench_data = load_data(idbench_data_path)
    # show_idbench_data(idbench_data)
    # fd = get_data_by_token(idbench_data, 'equal')
    fd_context, fd_ebd = build_pca_data(idbench_data)
    pca_fd = pca(fd_ebd)
    # print(pca_fd)
    # print(fd_context)
    info = fd_context
    # tokens = get_tokens(info)
    tokens = ['- - - ', 'equal', 'ok', 'eql', 'cut']
    visualize(pca_fd, fd_context, tokens)
    visualize(pca_fd, fd_context, tokens, show_all=True, show_label=False)

# %%
analyze_graph_with_idx_in_local()
analyze_graph_with_idx_in_local([0, 1])
# Out:
# get data by idx:  [0, 1, 2]
# number of items:  3
# [0.0, 0.12882404029369354, 0.3638933300971985, 0.22629283368587494, 0.3611290752887726, 0.24608255922794342, 0.2991713583469391, 0.011809343472123146, 0.4298560321331024, 0.2901725769042969, 0.0, 0.1991395652294159, 0.1673385053873062, 0.19488118588924408, 0.020157666876912117, 0.6029472351074219, 0.4906868040561676, 0.017933640629053116, 0.26981332898139954, 0.385983943939209, 0.0, 0.049202028661966324, 0.08136449754238129, 0.04205268993973732, 0.23146109282970428, 0.049776844680309296, 0.17002339661121368, 0.0004723737365566194, 0.10136996954679489, 0.07109960168600082, 0.0, 0.03174760192632675, 0.057855624705553055, 0.10161492973566055, 0.0008063066634349525, 0.37614741921424866, 0.29107609391212463, 0.0007173456251621246, 0.1466326266527176, 0.09178510308265686]
# /Users/jiaxingzhang/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /Users/jiaxingzhang/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:982: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(
# [[-1.13670397e+01 -5.31286526e+00]
#  [-1.55554190e+01 -1.23513830e+00]
#  [-2.19042416e+01  2.81904745e+00]
#  [-1.25323648e+01 -4.24720192e+00]
#  [-3.90930009e+00 -9.57347775e+00]
#  [-9.76767445e+00 -9.65038586e+00]
#  [-8.37861633e+00 -3.87631655e+00]
#  [-2.03146553e+01 -2.24135733e+00]
#  [-5.72053385e+00 -9.04733467e+00]
#  [-4.02069044e+00 -8.89879513e+00]
#  [-2.05637932e+01  3.27943015e+00]
#  [-2.18631897e+01  6.71553230e+00]
#  [-1.69502411e+01 -1.81236207e-01]
#  [-1.18504086e+01 -3.62757874e+00]
#  [-2.51897640e+01  4.79339647e+00]
#  [-2.43053932e+01  4.42006779e+00]
#  [-2.37263966e+01  9.52088737e+00]
#  [-2.60658169e+00 -9.32206345e+00]
#  [-1.65943451e+01  4.87791729e+00]
#  [-1.33760843e+01  1.82185739e-01]
#  [-2.87065339e+00 -1.06962290e+01]
#  [-1.29421215e+01 -1.18677020e+00]
#  [-2.17958794e+01  4.85604811e+00]
#  [-7.74048328e+00 -7.50302315e+00]
#  [-9.89665127e+00 -9.30129242e+00]
#  [-6.89543056e+00 -1.12700148e+01]
#  [-1.94260883e+01  1.02574252e-01]
#  [-9.47984219e+00 -5.79626513e+00]
#  [-6.02595711e+00 -5.67111206e+00]
#  [-1.60234222e+01  4.39576292e+00]
#  [-1.12504740e+01 -1.39410877e+00]
#  [-1.53313608e+01 -3.45461726e+00]
#  [-6.87958479e+00 -4.88619900e+00]
#  [-8.37940311e+00 -8.65147781e+00]
#  [-2.19109535e+01  5.71825552e+00]
#  [-1.47465496e+01 -5.20304155e+00]
#  [-2.59970913e+01  6.51549149e+00]
#  [-1.88016605e+01  8.00888911e-02]
#  [-2.59617176e+01  6.42339897e+00]
#  [-1.30663576e+01 -3.79606175e+00]
#  [-1.87022972e+01  3.10620737e+00]
#  [-2.35790253e+01  7.58786392e+00]
#  [-1.28832912e+01 -3.51877749e-01]
#  [-1.12407198e+01 -2.86235929e+00]
#  [-1.55967188e+01 -7.65522099e+00]
#  [-1.68530560e+01  1.58921921e+00]
#  [-1.10309763e+01 -7.43764782e+00]
#  [-2.11064510e+01  4.64192057e+00]
#  [-2.55849876e+01  1.01379633e+01]
#  [-4.44062328e+00 -1.13200579e+01]
#  [-1.40084972e+01  3.24897909e+00]
#  [-1.33645134e+01 -4.14959049e+00]
#  [-9.73173141e+00 -7.65287352e+00]
#  [-1.93804550e+01  3.00008583e+00]
#  [-2.43778858e+01  3.40971208e+00]
#  [-1.43999586e+01 -5.07888174e+00]
#  [-7.69266415e+00 -9.03339577e+00]
#  [-1.85094261e+01  1.21623170e+00]
#  [-2.86637268e+01  8.05471611e+00]
#  [-3.99622393e+00 -1.05693636e+01]
#  [-2.01985855e+01  7.50809908e-03]
#  [-3.62140203e+00 -1.20870142e+01]
#  [-1.19099741e+01 -8.74628353e+00]
#  [-1.70111389e+01  1.92035067e+00]
#  [-2.50252113e+01  7.51868773e+00]
#  [-1.29253635e+01 -6.96813202e+00]
#  [-7.05313778e+00 -8.80863762e+00]
#  [-6.90532255e+00 -7.77814722e+00]
#  [-2.51814976e+01  9.58416843e+00]
#  [-5.49357510e+00 -1.30844755e+01]
#  [-9.32520962e+00 -1.20725470e+01]
#  [-2.80077038e+01  9.54525948e+00]
#  [-2.05544395e+01 -3.11120844e+00]
#  [-1.99683399e+01  6.53038681e-01]
#  [-1.09240971e+01 -2.76045728e+00]
#  [-2.66850395e+01  9.22039127e+00]
#  [-1.45486698e+01 -3.86411965e-01]
#  [-7.48817205e+00 -6.28486967e+00]
#  [-1.31613598e+01 -2.95562935e+00]
#  [-2.94130917e+01  7.99965906e+00]
#  [-1.61783504e+01 -9.88847017e-01]
#  [-2.16385708e+01  7.70638275e+00]
#  [-1.70223732e+01 -3.62910318e+00]
#  [-1.98180561e+01 -4.74876451e+00]
#  [-1.84390163e+01  3.91255879e+00]
#  [-2.88826485e+01  1.01132574e+01]
#  [-1.61791344e+01  1.89945400e-01]
#  [-2.76884441e+01  8.13923836e+00]
#  [-4.72123909e+00 -8.39704132e+00]
#  [-2.35268650e+01  6.09909201e+00]
#  [-2.68454056e+01  8.50409794e+00]
#  [-4.15279150e+00 -8.22370148e+00]
#  [-1.97540989e+01 -2.71117139e+00]
#  [-1.02617531e+01 -7.30454779e+00]
#  [-2.03840599e+01 -3.91150618e+00]
#  [-1.76867027e+01 -4.01613569e+00]
#  [-1.31607628e+01  3.03949881e+00]
#  [-2.49738827e+01  4.74811935e+00]
#  [-2.56989021e+01  8.83770466e+00]
#  [-1.84002137e+00 -1.05134659e+01]
#  [-1.15526848e+01 -5.29269981e+00]
#  [-1.50766945e+01 -9.97862995e-01]
#  [-2.48201694e+01  4.06117725e+00]
#  [-1.06960354e+01 -3.77183723e+00]
#  [-5.52750158e+00 -1.06569853e+01]
#  [-1.04434977e+01 -1.05527678e+01]
#  [-9.00165272e+00 -2.83336258e+00]
#  [-2.05428810e+01 -1.80548704e+00]
#  [-6.05913925e+00 -9.26372719e+00]
#  [-5.19118595e+00 -9.21641254e+00]
#  [-1.90606766e+01  1.79954958e+00]
#  [-2.10524654e+01  5.71985006e+00]
#  [-1.68122959e+01 -7.46351063e-01]
#  [-1.25061436e+01 -3.03114486e+00]
#  [-2.57926903e+01  3.43956017e+00]
#  [-2.21758919e+01  4.85929108e+00]
#  [-2.38877068e+01  9.48810005e+00]
#  [-2.55188775e+00 -9.94224739e+00]
#  [-1.66639442e+01  4.94950342e+00]
#  [-1.31308947e+01 -1.06435888e-01]
#  [-3.04387188e+00 -9.19589233e+00]
#  [-1.48661366e+01 -6.79799223e+00]
#  [-2.41559391e+01  7.05987644e+00]
#  [-8.55482483e+00 -7.86974382e+00]
#  [-1.04562178e+01 -8.41873550e+00]
#  [-6.72174263e+00 -1.12740955e+01]
#  [-2.02670803e+01  1.26885653e+00]
#  [-9.50911331e+00 -5.67510796e+00]
#  [-7.26922989e+00 -7.42723036e+00]
#  [-1.54745216e+01  1.59468281e+00]
#  [-1.17210426e+01 -1.15692735e+00]
#  [-1.51734781e+01 -6.78119659e+00]
#  [-6.76364088e+00 -4.95931864e+00]
#  [-6.69272232e+00 -9.85578346e+00]
#  [-1.99592228e+01  4.21279049e+00]
#  [-1.48910189e+01 -4.88193798e+00]
#  [-2.61946125e+01  6.95730543e+00]
#  [-2.16741238e+01  3.87458491e+00]
#  [-2.73208408e+01  1.06174717e+01]
#  [-1.27841492e+01 -2.63587856e+00]
#  [-1.84557858e+01  2.76980114e+00]
#  [-2.47935638e+01  7.72515392e+00]
#  [-1.31546640e+01 -3.79789680e-01]
#  [-1.08988047e+01 -2.41710663e+00]
#  [-1.36405001e+01 -8.85170746e+00]
#  [-1.63651371e+01  2.70319915e+00]
#  [-1.37658148e+01 -6.80315351e+00]
#  [-2.08445244e+01  1.31106126e+00]
#  [-2.55203686e+01  1.01263514e+01]
#  [-4.73204613e+00 -1.15097151e+01]
#  [-1.43369350e+01  3.18245602e+00]
#  [-1.62155495e+01 -1.32515442e+00]
#  [-1.02977304e+01 -7.12166357e+00]
#  [-1.79341431e+01  2.03924942e+00]
#  [-2.40014458e+01  3.19067669e+00]
#  [-1.31590376e+01 -5.54279089e+00]
#  [-8.65012264e+00 -9.29559708e+00]
#  [-2.26810970e+01  5.25585556e+00]
#  [-2.90013313e+01  8.68475151e+00]
#  [-2.97254300e+00 -9.99881935e+00]
#  [-1.89075756e+01 -7.13404298e-01]
#  [-3.10532355e+00 -1.16502066e+01]
#  [-1.17613344e+01 -9.66949940e+00]
#  [-1.75123787e+01  1.86094594e+00]
#  [-2.46619625e+01  7.37053728e+00]
#  [-1.24093714e+01 -6.70947838e+00]
#  [-5.94723797e+00 -7.67472363e+00]
#  [-6.97507048e+00 -7.71818686e+00]
#  [-2.48311863e+01  9.67736053e+00]
#  [-9.23663902e+00 -1.24196768e+01]
#  [-9.05817127e+00 -1.18932428e+01]
#  [-2.73014851e+01  7.06532812e+00]
#  [-1.92778091e+01 -3.57621527e+00]
#  [-2.13465385e+01  3.92049360e+00]
#  [-1.42967911e+01 -7.38286018e+00]
#  [-2.71425457e+01  9.25020885e+00]
#  [-1.20303326e+01  1.43032515e+00]
#  [-8.23710728e+00 -6.74863482e+00]
#  [-1.38630714e+01 -7.79679966e+00]
#  [-2.94487839e+01  8.34762287e+00]
#  [-1.77603416e+01  8.45914602e-01]
#  [-2.28296738e+01  7.43903399e+00]
#  [-1.73537045e+01 -3.47422385e+00]
#  [-1.96950989e+01 -4.86992073e+00]
#  [-1.96376495e+01  1.42327940e+00]
#  [-2.15150223e+01 -4.12240744e+00]
#  [-1.58927889e+01 -5.44887543e-01]
#  [-2.78358669e+01  9.48776436e+00]
#  [-4.94434977e+00 -1.00670843e+01]
#  [-2.36082535e+01  6.36437988e+00]
#  [-2.76880760e+01  9.07678413e+00]
#  [-5.92163420e+00 -9.80207443e+00]
#  [-1.92708263e+01 -2.79544330e+00]
#  [-8.54509354e+00 -7.41459465e+00]
#  [-2.13321800e+01 -1.85348761e+00]
#  [-9.45793343e+00 -2.36429542e-01]
#  [-1.29264669e+01  2.92193770e+00]
#  [-2.28207455e+01  6.19095182e+00]
#  [-2.56631527e+01  8.93090534e+00]
#  [-2.23355460e+00 -1.07629776e+01]
#  [ 3.06014385e+01  2.72714925e+00]
#  [ 3.55663872e+01  8.64153802e-01]
#  [ 3.51454697e+01  6.26691294e+00]
#  [ 3.72424278e+01 -5.87324619e-01]
#  [ 3.18100147e+01  3.07307196e+00]
#  [ 3.55798950e+01  9.02722645e+00]
#  [ 3.17823582e+01  1.82241762e+00]
#  [ 3.96284485e+01 -4.30541694e-01]
#  [ 3.87226295e+01  7.72384584e-01]
#  [ 3.16594791e+01 -2.13677931e+00]
#  [ 3.54920006e+01  5.00728464e+00]
#  [ 4.08053551e+01 -7.75866807e-02]
#  [ 3.68171234e+01  5.03900337e+00]
#  [ 3.56070747e+01  4.30858994e+00]
#  [ 3.44378586e+01  8.32694054e+00]
#  [ 3.18030281e+01 -2.02717245e-01]
#  [ 3.30958176e+01  8.46673608e-01]
#  [ 3.30063248e+01  7.35403538e+00]
#  [ 3.68737602e+01 -3.73522609e-01]
#  [ 3.46968346e+01  8.42156696e+00]
#  [ 3.69858398e+01  9.62132549e+00]
#  [ 3.60487022e+01 -6.07395172e-01]
#  [ 3.54708061e+01 -1.94234163e-01]
#  [ 3.14880981e+01  3.87442470e+00]
#  [ 3.21465607e+01  6.82035065e+00]
#  [ 3.32883110e+01  3.18661857e+00]
#  [ 3.31293526e+01  2.02271223e+00]
#  [ 3.76060371e+01  2.18357420e+00]
#  [ 3.16155643e+01 -2.04048491e+00]
#  [ 3.87014351e+01  7.52329826e+00]
#  [ 3.59927559e+01  8.85448837e+00]
#  [ 3.28856354e+01  3.33582497e+00]
#  [ 3.83086472e+01  1.61986744e+00]
#  [ 3.41699944e+01  7.15140295e+00]
#  [ 3.80568199e+01  3.98932076e+00]
#  [ 3.63588715e+01  8.24032497e+00]
#  [ 3.74785919e+01  4.87162161e+00]
#  [ 3.37433281e+01  1.38287008e+00]
#  [ 3.37309837e+01  5.38150978e+00]
#  [ 3.57761192e+01  2.18955159e+00]
#  [ 3.78352928e+01  3.47791696e+00]
#  [ 3.69154205e+01  8.89966106e+00]
#  [ 3.87128716e+01 -4.44139302e-01]
#  [ 3.26677322e+01  1.23910868e+00]
#  [ 3.28421288e+01  4.05101681e+00]
#  [ 3.72849617e+01  7.37574816e+00]
#  [ 3.19495869e+01  8.82482708e-01]
#  [ 3.62191696e+01 -4.68518436e-01]
#  [ 3.53369446e+01 -1.79307890e+00]
#  [ 3.64408073e+01  9.40938187e+00]
#  [ 3.80815392e+01 -6.83488846e-01]
#  [ 3.63976440e+01  5.24570894e+00]
#  [ 3.75371246e+01  9.11726761e+00]
#  [ 3.65898170e+01  9.95076835e-01]
#  [ 3.00625725e+01  3.07613730e+00]
#  [ 3.38330040e+01  1.33605689e-01]
#  [ 3.40259132e+01 -8.03892314e-01]
#  [ 3.26598816e+01  2.03002763e+00]
#  [ 3.88938179e+01  7.80689764e+00]
#  [ 3.79476662e+01  8.41757393e+00]
#  [ 3.21636543e+01  1.81100643e+00]
#  [ 3.65537224e+01 -1.07533848e+00]
#  [ 3.97397003e+01 -1.36056316e+00]
#  [ 3.77862282e+01 -6.05011731e-02]
#  [ 3.10991840e+01  1.35226035e+00]
#  [ 3.80834007e+01  9.11366272e+00]
#  [ 3.55270233e+01  4.70503139e+00]
#  [ 3.17343578e+01  1.96075320e+00]
#  [ 3.90365906e+01  6.00027943e+00]
#  [ 3.82098007e+01  2.35102654e+00]
#  [ 3.81666183e+01  2.34762132e-01]
#  [ 3.89092369e+01  8.54861736e+00]
#  [ 3.13569050e+01  4.61859083e+00]
#  [ 4.20080490e+01  4.43523645e+00]
#  [ 4.13942299e+01  4.10678625e+00]
#  [ 3.79347649e+01 -1.22085273e+00]
#  [ 3.61824913e+01  9.66155529e+00]
#  [ 3.22524376e+01 -1.41246796e+00]
#  [ 4.12904625e+01  4.04104233e+00]
#  [ 4.01740570e+01  7.17937648e-01]
#  [ 3.52949905e+01  7.95527220e-01]
#  [ 3.91976700e+01  7.96037579e+00]
#  [ 4.22086945e+01  4.54858589e+00]
#  [ 3.10287476e+01  2.26800275e+00]
#  [ 3.24467163e+01 -1.58881879e+00]
#  [ 3.71201591e+01  7.15649843e-01]
#  [ 3.76362076e+01  9.58677483e+00]
#  [ 3.64611015e+01  3.91773194e-01]
#  [ 3.42337761e+01  5.19977570e+00]
#  [ 3.60408592e+01  5.46767235e-01]
#  [ 3.55986977e+01  3.57995558e+00]
#  [ 3.28478088e+01  7.59921217e+00]
#  [ 3.94338684e+01 -2.01052457e-01]
#  [ 3.73217621e+01  2.80884409e+00]
#  [ 3.70745544e+01  8.37858391e+00]
#  [ 3.25784149e+01  1.30195951e+00]
#  [ 3.34771996e+01 -4.59300429e-01]
#  [ 3.90747566e+01  3.22578907e-01]
#  [ 3.77446365e+01  7.02070832e-01]
#  [ 3.21721916e+01  5.64684963e+00]]
